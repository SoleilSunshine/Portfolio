# %% [markdown]
# # Cars Dataset

# %% [markdown]
# Goal: Read, Analyze and Visualize this dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel('../ds-la-09/exercises/08-cars-challenge/cars_2015_mpg.xlsx')

# %%
data.head()
# Out:
#    YEAR              MANUFACTURER          MODEL  VOLUME  CYLINDERS  GEARS  \
# 0  2015                Alfa Romeo             4C     1.8          4      6
# 1  2015  Aston Martin Lagonda Ltd  V12 Vantage S     6.0         12      7
# 2  2015  Aston Martin Lagonda Ltd     V8 Vantage     4.7          8      7
# 3  2015  Aston Martin Lagonda Ltd     V8 Vantage     4.7          8      6
# 4  2015  Aston Martin Lagonda Ltd   V8 Vantage S     4.7          8      7
#
#   FWD_RWD          DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  \
# 0       R  2-Wheel Drive, Rear        24       34            28       365
# 1       R  2-Wheel Drive, Rear        12       18            14       742
# 2       R  2-Wheel Drive, Rear        14       21            16       655
# 3       R  2-Wheel Drive, Rear        13       19            15       681
# 4       R  2-Wheel Drive, Rear        14       21            16       655
#
#    CO2_HWY  CO2_COMBINED
# 0      259           317
# ...

# %%
data['MPG_COMBINED'][0:15]
# Out:
# 0     28
# 1     14
# 2     16
# 3     15
# 4     16
# 5     15
# 6     16
# 7     15
# 8     17
# 9     14
# 10    16
# 11    14
# 12    17
# 13    14
# 14    16
# Name: MPG_COMBINED, dtype: int64

# %%
data.max()
# Out:
# YEAR            2015.0
# VOLUME             8.4
# CYLINDERS         16.0
# GEARS              9.0
# MPG_CITY          53.0
# MGP_HWY           48.0
# MPG_COMBINED      50.0
# CO2_CITY        1050.0
# CO2_HWY          624.0
# CO2_COMBINED     847.0
# dtype: float64

# %%
data[data['MPG_COMBINED']==50]
# Out:
#      YEAR MANUFACTURER    MODEL  VOLUME  CYLINDERS  GEARS FWD_RWD  \
# 420  2015       TOYOTA  PRIUS c     1.5          4      1       F
# 640  2015       TOYOTA    PRIUS     1.8          4      1       F
#
#               DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  CO2_HWY  \
# 420  2-Wheel Drive, Front        53       46            50       168      192
# 640  2-Wheel Drive, Front        51       48            50       174      183
#
#      CO2_COMBINED
# 420           178
# 640           178

# %%
data.ix[data.MPG_COMBINED==np.max(data.MPG_COMBINED), :]
# Out:
#      YEAR MANUFACTURER    MODEL  VOLUME  CYLINDERS  GEARS FWD_RWD  \
# 420  2015       TOYOTA  PRIUS c     1.5          4      1       F
# 640  2015       TOYOTA    PRIUS     1.8          4      1       F
#
#               DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  CO2_HWY  \
# 420  2-Wheel Drive, Front        53       46            50       168      192
# 640  2-Wheel Drive, Front        51       48            50       174      183
#
#      CO2_COMBINED
# 420           178
# 640           178

# %%
data.min()
# Out:
# YEAR            2015
# VOLUME             1
# CYLINDERS          3
# GEARS              1
# MPG_CITY           8
# MGP_HWY           14
# MPG_COMBINED      10
# CO2_CITY         168
# CO2_HWY          177
# CO2_COMBINED     178
# dtype: float64

# %%
data.ix[178,'CO2_COMBINED']
# Out:
# 374

# %%
data.describe()
# Out:
#        YEAR       VOLUME    CYLINDERS        GEARS     MPG_CITY      MGP_HWY  \
# count  1232  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean   2015     3.264367     5.729708     6.397727    20.153409    27.928571
# std       0     1.384939     1.844700     1.408202     5.527423     6.182029
# min    2015     1.000000     3.000000     1.000000     8.000000    14.000000
# 25%    2015     2.000000     4.000000     6.000000    16.000000    23.000000
# 50%    2015     3.000000     6.000000     6.000000    19.000000    27.500000
# 75%    2015     3.800000     6.000000     7.000000    23.000000    32.000000
# max    2015     8.400000    16.000000     9.000000    53.000000    48.000000
#
#        MPG_COMBINED     CO2_CITY      CO2_HWY  CO2_COMBINED
# count   1232.000000  1232.000000  1232.000000   1232.000000
# mean      22.965909   473.239448   335.655844    411.293831
# std        5.685114   122.640050    76.549162    100.460943
# ...

# %%
data[data['CO2_COMBINED']<179]
# Out:
#      YEAR MANUFACTURER    MODEL  VOLUME  CYLINDERS  GEARS FWD_RWD  \
# 420  2015       TOYOTA  PRIUS c     1.5          4      1       F
# 640  2015       TOYOTA    PRIUS     1.8          4      1       F
#
#               DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  CO2_HWY  \
# 420  2-Wheel Drive, Front        53       46            50       168      192
# 640  2-Wheel Drive, Front        51       48            50       174      183
#
#      CO2_COMBINED
# 420           178
# 640           178

# %%
data[['VOLUME', 'MPG_CITY']].corr()
# Out:
#             VOLUME  MPG_CITY
# VOLUME    1.000000 -0.764311
# MPG_CITY -0.764311  1.000000

# %%
data[['MPG_CITY', 'MGP_HWY']].corr()
# Out:
#           MPG_CITY   MGP_HWY
# MPG_CITY  1.000000  0.910289
# MGP_HWY   0.910289  1.000000

# %%
data.corr()
# Out:
#               YEAR    VOLUME  CYLINDERS     GEARS  MPG_CITY   MGP_HWY  \
# YEAR           NaN       NaN        NaN       NaN       NaN       NaN
# VOLUME         NaN  1.000000   0.925112  0.266896 -0.764311 -0.783647
# CYLINDERS      NaN  0.925112   1.000000  0.323175 -0.740763 -0.739675
# GEARS          NaN  0.266896   0.323175  1.000000 -0.399422 -0.235804
# MPG_CITY       NaN -0.764311  -0.740763 -0.399422  1.000000  0.910289
# MGP_HWY        NaN -0.783647  -0.739675 -0.235804  0.910289  1.000000
# MPG_COMBINED   NaN -0.795330  -0.763085 -0.346347  0.985509  0.961812
# CO2_CITY       NaN  0.867037   0.851798  0.304054 -0.918436 -0.905335
# CO2_HWY        NaN  0.814849   0.770175  0.183520 -0.849205 -0.949975
# CO2_COMBINED   NaN  0.860799   0.835214  0.267232 -0.906508 -0.931952
#
#               MPG_COMBINED  CO2_CITY   CO2_HWY  CO2_COMBINED
# YEAR                   NaN       NaN       NaN           NaN
# VOLUME           -0.795330  0.867037  0.814849      0.860799
# ...

# %%
np.mean(data.ix[data.DRIVE_DESCR=="All Wheel Drive", 'MPG_COMBINED'])
# Out:
# 21.958904109589042

# %%
data.ix[(data.DRIVE_DESCR=="All Wheel Drive") & (data.VOLUME>=3.0) & (data.GEARS % 2 ==0), :]
# Out:
#       YEAR                      MANUFACTURER                          MODEL  \
# 9     2015                              Audi                             R8
# 11    2015                              Audi                             R8
# 13    2015                              Audi                      R8 Spyder
# 15    2015                              Audi                      R8 Spyder
# 17    2015                           Bentley              Continental GT3-R
# 164   2015                              Audi                             S5
# 167   2015                           Bentley     Continental GT Convertible
# 168   2015                           Bentley     Continental GT Convertible
# 177   2015                               BMW        435i xDrive Convertible
# 180   2015                               BMW        640i xDrive Convertible
# 181   2015                               BMW              640i xDrive Coupe
# ...

# %%
np.mean(data.ix[(data.DRIVE_DESCR=="All Wheel Drive") & (data.VOLUME>=3.0) & (data.GEARS % 2 ==0), ['MPG_COMBINED']])
# Out:
# MPG_COMBINED    20.433566
# dtype: float64

# %%
data.ix[:,'MPG_COMBINED'].hist()

# %%
data.ix[(data.DRIVE_DESCR=="All Wheel Drive") & (data.VOLUME>=3.0) & (data.GEARS % 2 ==0), 'CYLINDERS'].hist()

# %%
data.ix[:, 'CYLINDERS'].hist()

# %%
plt.plot(data['CO2_COMBINED'])

# %%
plt.plot(data['VOLUME'])

# %%
plt.scatter(data['CO2_COMBINED'], data['VOLUME'])

# %%
data[['CO2_COMBINED', 'VOLUME']].corr()
# Out:
#               CO2_COMBINED    VOLUME
# CO2_COMBINED      1.000000  0.860799
# VOLUME            0.860799  1.000000

# %%
plt.plot(data['GEARS'])

# %%
plt.plot(data['MPG_COMBINED'])

# %%
plt.scatter(data['GEARS'], data['MPG_COMBINED'])

# %%
data[['GEARS', 'MPG_COMBINED']].corr()
# Out:
#                  GEARS  MPG_COMBINED
# GEARS         1.000000     -0.346347
# MPG_COMBINED -0.346347      1.000000

# %%
plt.scatter(data['VOLUME'], data['MPG_COMBINED'])

# %%
data[['VOLUME', 'MPG_COMBINED']].corr()
# Out:
#                VOLUME  MPG_COMBINED
# VOLUME        1.00000      -0.79533
# MPG_COMBINED -0.79533       1.00000

# %%
data.plot()
